# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Amazon.csv")
df
# Out:
#         Year  Billion USD
# 0    2013 Q1         16.1
# 1    2013 Q2         15.7
# 2    2013 Q3         17.1
# 3    2013 Q4         25.6
# 4    2014 Q1         19.7
# 5    2014 Q2         19.3
# 6    2014 Q3         20.6
# 7    2014 Q4         29.3
# 8    2015 Q1         22.7
# 9    2015 Q2         23.2
# 10   2015 Q3         25.4
# 11   2015 Q4         35.7
# 12   2016 Q1         29.1
# 13   2016 Q2         30.4
# 14   2016 Q3         32.7
# 15   2016 Q4         43.7
# 16   2017 Q1         35.7
# 17   2017 Q2         38.0
# 18   2017 Q3         43.7
# 19   2017 Q4         60.5
# 20   2018 Q1         51.0
# 21   2018 Q2         52.9
# 22  2018 Q3          56.6
# 23   2018 Q4         72.4
# 24   2019 Q1         59.7
# 25   2019 Q2         63.4
# 26   2019 Q3         70.0
# 27   2019 Q4         87.4
# 28  2020 Q1          75.5
# 29   2020 Q2         88.9
# 30   2020 Q3         96.1
# 31  2020 Q4         126.0
# 32   2021 Q1        109.0
# 33   2021 Q2        113.0
# ...

# %%
# limpando valores do dataframe
df = df.dropna()
df
# Out:
#         Year  Billion USD
# 0    2013 Q1         16.1
# 1    2013 Q2         15.7
# 2    2013 Q3         17.1
# 3    2013 Q4         25.6
# 4    2014 Q1         19.7
# 5    2014 Q2         19.3
# 6    2014 Q3         20.6
# 7    2014 Q4         29.3
# 8    2015 Q1         22.7
# 9    2015 Q2         23.2
# 10   2015 Q3         25.4
# 11   2015 Q4         35.7
# 12   2016 Q1         29.1
# 13   2016 Q2         30.4
# 14   2016 Q3         32.7
# 15   2016 Q4         43.7
# 16   2017 Q1         35.7
# 17   2017 Q2         38.0
# 18   2017 Q3         43.7
# 19   2017 Q4         60.5
# 20   2018 Q1         51.0
# 21   2018 Q2         52.9
# 22  2018 Q3          56.6
# 23   2018 Q4         72.4
# 24   2019 Q1         59.7
# 25   2019 Q2         63.4
# 26   2019 Q3         70.0
# 27   2019 Q4         87.4
# 28  2020 Q1          75.5
# 29   2020 Q2         88.9
# 30   2020 Q3         96.1
# 31  2020 Q4         126.0
# 32   2021 Q1        109.0
# 33   2021 Q2        113.0
# ...

# %%
# analisando os maiores valores
df_ordem1 = df.sort_values(by="Billion USD", ascending=False)
df_ordem1
# Out:
#         Year  Billion USD
# 43   2023 Q4        170.0
# 39   2022 Q4        149.0
# 42   2023 Q3        143.0
# 35  2021 Q4         137.0
# 41   2023 Q2        134.0
# 40   2023 Q1        127.0
# 38   2022 Q3        127.0
# 31  2020 Q4         126.0
# 37   2022 Q2        121.0
# 36   2022 Q1        116.0
# 33   2021 Q2        113.0
# 34   2021 Q3        111.0
# 32   2021 Q1        109.0
# 30   2020 Q3         96.1
# 29   2020 Q2         88.9
# 27   2019 Q4         87.4
# 28  2020 Q1          75.5
# 23   2018 Q4         72.4
# 26   2019 Q3         70.0
# 25   2019 Q2         63.4
# 19   2017 Q4         60.5
# 24   2019 Q1         59.7
# 22  2018 Q3          56.6
# 21   2018 Q2         52.9
# 20   2018 Q1         51.0
# 18   2017 Q3         43.7
# 15   2016 Q4         43.7
# 17   2017 Q2         38.0
# 11   2015 Q4         35.7
# 16   2017 Q1         35.7
# 14   2016 Q3         32.7
# 13   2016 Q2         30.4
# 7    2014 Q4         29.3
# 12   2016 Q1         29.1
# ...

# %%
# analisando a tendência de crescimento ou queda com o passar dos anos
df_ordem = df.sort_values(by="Year", ascending=True)
df_ordem
# Out:
#         Year  Billion USD
# 0    2013 Q1         16.1
# 1    2013 Q2         15.7
# 2    2013 Q3         17.1
# 3    2013 Q4         25.6
# 4    2014 Q1         19.7
# 5    2014 Q2         19.3
# 6    2014 Q3         20.6
# 7    2014 Q4         29.3
# 8    2015 Q1         22.7
# 9    2015 Q2         23.2
# 10   2015 Q3         25.4
# 11   2015 Q4         35.7
# 12   2016 Q1         29.1
# 13   2016 Q2         30.4
# 14   2016 Q3         32.7
# 15   2016 Q4         43.7
# 16   2017 Q1         35.7
# 17   2017 Q2         38.0
# 18   2017 Q3         43.7
# 19   2017 Q4         60.5
# 20   2018 Q1         51.0
# 21   2018 Q2         52.9
# 22  2018 Q3          56.6
# 23   2018 Q4         72.4
# 24   2019 Q1         59.7
# 25   2019 Q2         63.4
# 26   2019 Q3         70.0
# 27   2019 Q4         87.4
# 28  2020 Q1          75.5
# 29   2020 Q2         88.9
# 30   2020 Q3         96.1
# 31  2020 Q4         126.0
# 32   2021 Q1        109.0
# 33   2021 Q2        113.0
# ...

# %%
#analisando o crescimento em porcentagens
df['Growth Rate (%)'] = df['Billion USD'].pct_change() * 100
df['Growth Rate (%)'] = df['Growth Rate (%)'].fillna(0)
df
# Out:
#         Year  Billion USD  Growth Rate (%)
# 0    2013 Q1         16.1         0.000000
# 1    2013 Q2         15.7        -2.484472
# 2    2013 Q3         17.1         8.917197
# 3    2013 Q4         25.6        49.707602
# 4    2014 Q1         19.7       -23.046875
# 5    2014 Q2         19.3        -2.030457
# 6    2014 Q3         20.6         6.735751
# 7    2014 Q4         29.3        42.233010
# 8    2015 Q1         22.7       -22.525597
# 9    2015 Q2         23.2         2.202643
# 10   2015 Q3         25.4         9.482759
# 11   2015 Q4         35.7        40.551181
# 12   2016 Q1         29.1       -18.487395
# 13   2016 Q2         30.4         4.467354
# 14   2016 Q3         32.7         7.565789
# 15   2016 Q4         43.7        33.639144
# 16   2017 Q1         35.7       -18.306636
# 17   2017 Q2         38.0         6.442577
# 18   2017 Q3         43.7        15.000000
# 19   2017 Q4         60.5        38.443936
# 20   2018 Q1         51.0       -15.702479
# ...

# %%
# convertendo valores em variaveis para a criação do gráfico
df_y = df['Year']
df_x = df['Billion USD']

# %%
plt.figure(figsize=(15, 9))
plt.bar(df_y, df_x)
plt.xlabel('Year')
plt.xticks(rotation=90) # ajustando a rotação para evitar sobreposição
plt.tight_layout()
plt.ylabel('Bilhões em USD')
plt.title('Gráfico de Barras')
plt.show()

# %%
# salvando o arquivo modificado em csv
df.to_csv('Amazon_modificado.csv', index=False)
